# %%
# read each line of the file
file_name = 'q_table_4x4_abstracted_test.txt'

with open(file_name, 'r') as f:
    for line_num, line in enumerate(f):
        state_raw, action, q_value_raw = line.strip().split(';')

        state_raw = state_raw.strip('()').split(', ')

        state = []
        for i in range(len(state_raw)):
            state.append(int(state_raw[i]))

        state = tuple(state)

        q_value_raw = q_value_raw.strip('()').split(', ')
        q_value_count = (float(q_value_raw[0]), int(q_value_raw[1]))

        # print(f"{line_num}: State: {state}, Action: {action}, Q-value: {q_value_count}")
        
        # if line_num == 7:
        #     line7 = (state, action, q_value_count)
        #     print(f"Line 7: {line7}")

        if line_num == 8:
            line8 = (state, action, q_value_count)
            line8state = state
            line8action = action
            line8q_value_count = q_value_count
            print(f"Line 8: {line8}")

        if line_num == 9:
            line9 = (state, action, q_value_count)
            line9state = state
            line9action = action
            line9q_value_count = q_value_count
            print(f"Line 9: {line9}")

            print(f'equivalence check: {line8state == line9state}, {line8action == line9action}, {line8q_value_count == line9q_value_count}')

        if line_num == 10:
            break
# Out:
# Line 8: ((2, 1, 1, 2, 2, 3), 'False', (0.023555045844272177, 2))
# Line 9: ((2, 1, 1, 2, 2, 3), 'False', (0.05467366435071907, 1))
# equivalence check: True, True, False
